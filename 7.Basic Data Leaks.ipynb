# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)



import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# ## Leaks in time series
# 1. Split should be done on time.
#    - In real life we don't have information from future
#    - In competitions first thing to look: train/public/private split, is it on time?
#
#
# 2. Even when split by time, features may contain information about future.
#    - User history in CTR tasks
#    - Weather

# %% [markdown]
# ## Unexpected Information
# - Meta data --> file creation date, resolution maybe this has correlation with the target
# - Information in IDs --> Maybe has the correlation to the target ?
# - Row order --> row duplicate, sometimes has the same label --> overcome this!

# %% [markdown]
# ## Leaderboard Probing
# Two types of LB probing :
#
# 1. Extract the ground truth from public leaderboard --> harmless, because Only small training in the data
# 2. Adapting global mean via LB probing
#
# -  Categories tightly connected with 'id' are vulnerable to LB probing

# %%
rows = [[1,0],[1,0],[1,0],[2,1],[2,1],[2,1]]
df = pd.DataFrame(rows, columns = ['id','y'])
df

# %% [markdown]
# rows with same id has the same target!
